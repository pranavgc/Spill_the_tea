# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('Trial_dataset1_10000_with_GoogleReviews.csv',encoding='latin-1', usecols = [' CompanyNumber','Google_Overall_Rating','Google_Price_Level','Google_Review_Texts','Google_Individual_Review_Ratings'])
df2 = pd.read_csv('Trial_dataset10001_20000_with_GoogleReviews.csv',encoding='latin-1', usecols = [' CompanyNumber','Google_Overall_Rating','Google_Price_Level','Google_Review_Texts','Google_Individual_Review_Ratings'])
df3 = pd.read_csv('Trial_dataset22501_25269.csv',encoding='latin-1')

# %%
df1.head()
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       SC780693                    4.7                 NaN
# 1       SC402065                    4.2                 1.0
# 2       SC444940                    4.6                 NaN
# 3       SC857241                    4.7                 2.0
# 4       11215147                    4.8                 NaN
#
#                                  Google_Review_Texts  \
# 0  Highly Recommended â M-Brothers Automotive B...
# 1  Small but friendly establishment. Couple of TV...
# 2  The best vegan pizza in Inverclyde! Absolutely...
# 3  Food was great! My husband said it was the bes...
# 4  Best pint of bass I have had in a long time fr...
#
#   Google_Individual_Review_Ratings
# 0                5 | 5 | 5 | 5 | 5
# 1                5 | 5 | 5 | 1 | 5
# 2                5 | 5 | 5 | 5 | 5
# 3                4 | 5 | 1 | 4 | 4
# 4                5 | 5 | 5 | 5 | 5

# %%
df2.head()
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       12839866                    3.9                 NaN
# 1       16555427                    4.0                 NaN
# 2       12901062                    NaN                 NaN
# 3       NI680239                    4.2                 NaN
# 4       15816064                    4.0                 NaN
#
#                                  Google_Review_Texts  \
# 0  Whilst I respect and understand that Iâm lea...
# 1  My family orders from here at least once a mon...
# 2                                                NaN
# 3  I tested the doner kebab in naan bread with sa...
# 4  Weâre regular customers here but the last 2 ...
#
#   Google_Individual_Review_Ratings
# 0                1 | 5 | 5 | 5 | 1
# 1                2 | 2 | 5 | 5 | 5
# 2                              NaN
# 3                4 | 5 | 5 | 5 | 1
# 4                2 | 5 | 1 | 5 | 5

# %%
df3.head()
# Out:
#    CompanyNumber              CompanyName RegAddress.PostCode
# 0       16349234  NARDOS KITCHEN & BAKERY              LS97BG
# 1       15860923          LA FIESTA LEEDS              LS28BT
# 2       16403992           RUMBLES WELDON             NN173GY
# 3       15998193           R AROMA BISTRO              CV11LB
# 4       16479314             KOYUNCU 1989              N182NA

# %%
complete_df = pd.concat([df1,df2],axis=0)

# %%
complete_df.isna().sum()
# Out:
#  CompanyNumber                          0
# Google_Overall_Rating                4340
# Google_Price_Level                  14630
# Google_Review_Texts                  4423
# Google_Individual_Review_Ratings     4349
# dtype: int64

# %%
complete_df.head()
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       SC780693                    4.7                 NaN
# 1       SC402065                    4.2                 1.0
# 2       SC444940                    4.6                 NaN
# 3       SC857241                    4.7                 2.0
# 4       11215147                    4.8                 NaN
#
#                                  Google_Review_Texts  \
# 0  Highly Recommended â M-Brothers Automotive B...
# 1  Small but friendly establishment. Couple of TV...
# 2  The best vegan pizza in Inverclyde! Absolutely...
# 3  Food was great! My husband said it was the bes...
# 4  Best pint of bass I have had in a long time fr...
#
#   Google_Individual_Review_Ratings
# 0                5 | 5 | 5 | 5 | 5
# 1                5 | 5 | 5 | 1 | 5
# 2                5 | 5 | 5 | 5 | 5
# 3                4 | 5 | 1 | 4 | 4
# 4                5 | 5 | 5 | 5 | 5

# %%
incomplete_df = complete_df[complete_df['Google_Overall_Rating'].isna()]

# %%
incomplete_df
# Out:
#       CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 12         15581389                    NaN                 NaN
# 14          7885142                    NaN                 NaN
# 15         14486927                    NaN                 NaN
# 17         SC847346                    NaN                 NaN
# 21          9317797                    NaN                 NaN
# ...             ...                    ...                 ...
# 9966       16154270                    NaN                 NaN
# 9980       15971484                    NaN                 NaN
# 9991       17004630                    NaN                 NaN
# 9992        9296071                    NaN                 NaN
# 9994       16188473                    NaN                 NaN
#
#      Google_Review_Texts Google_Individual_Review_Ratings
# 12                   NaN                              NaN
# 14                   NaN                              NaN
# ...

# %%
complete_df = pd.concat([complete_df, incomplete_df]).drop_duplicates(keep=False)

# %%
complete_df.isna().sum()
# Out:
#  CompanyNumber                          0
# Google_Overall_Rating                   0
# Google_Price_Level                  10290
# Google_Review_Texts                    83
# Google_Individual_Review_Ratings        9
# dtype: int64

# %%
incomplete_df = incomplete_df.drop(['Google_Overall_Rating','Google_Price_Level'],axis=1)

# %%
df3 = df3.drop(['CompanyName','RegAddress.PostCode'],axis =1)

# %%
incomplete_df.head()
# Out:
#    CompanyNumber
# 12      15581389
# 14       7885142
# 15      14486927
# 17      SC847346
# 21       9317797

# %%
df3.head()
# Out:
#   CompanyNumber
# 0      16349234
# 1      15860923
# 2      16403992
# 3      15998193
# 4      16479314

# %%
incomplete_df = pd.concat([df3,incomplete_df]).drop_duplicates(keep=False)

# %%
incomplete_df
# Out:
#      CompanyNumber
# 0         16349234
# 1         15860923
# 2         16403992
# 3         15998193
# 4         16479314
# ...            ...
# 9966      16154270
# 9980      15971484
# 9991      17004630
# 9992       9296071
# 9994      16188473
#
# [7110 rows x 1 columns]

# %%
incomplete_df.to_excel('Quer_file.xlsx',index = False)

# %%
complete_df.to_excel('Query_complete.xlsx',index = False)
