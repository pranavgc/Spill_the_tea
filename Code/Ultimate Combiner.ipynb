# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('Query_complete.xlsx')
df1_sub1 = pd.read_csv('Trial_dataset1_10000_with_GoogleReviews.csv')
df1_sub2 = pd.read_csv('Trial_dataset10001_20000_with_GoogleReviews.csv')

# %%
df1.head(10)
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       SC780693                    4.7                 NaN
# 1       SC402065                    4.2                 1.0
# 2       SC444940                    4.6                 NaN
# 3       SC857241                    4.7                 2.0
# 4       11215147                    4.8                 NaN
# 5       16519529                    4.6                 1.0
# 6       16379120                    4.5                 1.0
# 7       SC531326                    4.6                 2.0
# 8        8589456                    5.0                 NaN
# 9       15478214                    4.6                 NaN
#
#    Google_Review_Texts  Google_Individual_Review_Ratings
# 0                  NaN                               NaN
# 1                  NaN                               NaN
# 2                  NaN                               NaN
# 3                  NaN                               NaN
# ...

# %%
df1.isna().sum()
# Out:
#  CompanyNumber                          0
# Google_Overall_Rating                   0
# Google_Price_Level                  10290
# Google_Review_Texts                 15659
# Google_Individual_Review_Ratings    15659
# dtype: int64

# %%
df1_sub1.head(10)
# Out:
#    CompanyNumber            CompanyName RegAddress.PostCode  \
# 0       SC780693            M&S MAZZONI             PA145ED
# 1       SC402065         LIGHTHOUSE BAR             PA151DG
# 2       SC444940  RISTORANTE ARLECCHINO             PA151XG
# 3       SC857241                AF EATS             PA169AP
# 4       11215147       THE GATE INN CO.             DE551AQ
# 5       16519529               CLIFFINN              DE45DP
# 6       16379120              KASHMIR 1             GL522LH
# 7       SC531326  SPICE GARDEN STIRLING              FK82LT
# 8        8589456         TUMAN CATERING              CR07RB
# 9       15478214                 RIZGAR              CR52NG
#
#    Google_Overall_Rating  Google_Price_Level  \
# 0                    4.7                 NaN
# 1                    4.2                 1.0
# 2                    4.6                 NaN
# 3                    4.7                 2.0
# 4                    4.8                 NaN
# ...

# %%
df1_sub2.head(10)
# Out:
#    CompanyNumber         CompanyName RegAddress.PostCode  \
# 0       12839866          CASA PARMO              B128JY
# 1       16555427        GOLDEN 88 RB              B448NQ
# 2       12901062        HNA BROTHERS              B296JE
# 3       NI680239       BAY OF BENGAL             BT808EE
# 4       15816064   YUMMIES TAKE AWAY              NE15RG
# 5       13598597       LUCKYTEA 0086              SW82FR
# 6       12162967  PICAPAU RESTAURANT             PE301EJ
# 7       14984903           YUMMY 588              WF75EG
# 8       SC813888   AULD HOOSE PUB 30              ML28NN
# 9       12916416        GRIFFIN CAFE             CM187BL
#
#    Google_Overall_Rating  Google_Price_Level  \
# 0                    3.9                 NaN
# 1                    4.0                 NaN
# 2                    NaN                 NaN
# 3                    4.2                 NaN
# 4                    4.0                 NaN
# 5                    4.3                 NaN
# ...

# %%
df1_sub1.columns
# Out:
# Index([' CompanyNumber', 'CompanyName', 'RegAddress.PostCode',
#        'Google_Overall_Rating', 'Google_Price_Level', 'Google_Review_Texts',
#        'Google_Individual_Review_Ratings', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14'],
#       dtype='object')

# %%
df1_sub1 = df1_sub1[[' CompanyNumber','Google_Overall_Rating','Google_Price_Level','Google_Review_Texts','Google_Individual_Review_Ratings']]

# %%
df1_sub1.head(10)
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       SC780693                    4.7                 NaN
# 1       SC402065                    4.2                 1.0
# 2       SC444940                    4.6                 NaN
# 3       SC857241                    4.7                 2.0
# 4       11215147                    4.8                 NaN
# 5       16519529                    4.6                 1.0
# 6       16379120                    4.5                 1.0
# 7       SC531326                    4.6                 2.0
# 8        8589456                    5.0                 NaN
# 9       15478214                    4.6                 NaN
#
#                                  Google_Review_Texts  \
# 0  Highly Recommended – M-Brothers Automotive Bri...
# 1  Small but friendly establishment. Couple of TV...
# 2  The best vegan pizza in Inverclyde! Absolutely...
# 3  Food was great! My husband said it was the bes...
# ...

# %%
df1_sub2 = df1_sub2[[' CompanyNumber','Google_Overall_Rating','Google_Price_Level','Google_Review_Texts','Google_Individual_Review_Ratings']]

# %%
df1_sub2.head()
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       12839866                    3.9                 NaN
# 1       16555427                    4.0                 NaN
# 2       12901062                    NaN                 NaN
# 3       NI680239                    4.2                 NaN
# 4       15816064                    4.0                 NaN
#
#                                  Google_Review_Texts  \
# 0  Whilst I respect and understand that I’m leavi...
# 1  My family orders from here at least once a mon...
# 2                                                NaN
# 3  I tested the doner kebab in naan bread with sa...
# 4  We’re regular customers here but the last 2 ti...
#
#   Google_Individual_Review_Ratings
# 0                1 | 5 | 5 | 5 | 1
# 1                2 | 2 | 5 | 5 | 5
# 2                              NaN
# 3                4 | 5 | 5 | 5 | 1
# 4                2 | 5 | 1 | 5 | 5

# %%
df1_sub = pd.concat([df1_sub1, df1_sub2]).drop_duplicates(keep=False)

# %%
len(df1_sub)
# Out:
# 19999

# %%
len(df1_sub1)
# Out:
# 9999

# %%
len(df1_sub2)
# Out:
# 10000

# %%
len(df1)
# Out:
# 15659

# %%
df1.set_index(' CompanyNumber', inplace=True)
df1_sub.set_index(' CompanyNumber', inplace=True)

# 2. Overwrite df1 with values from df2
df1.update(df1_sub)

# 3. Reset index to bring 'place_id' back as a column
df1.reset_index(inplace=True)
# Out:
# C:\Users\hdar0\AppData\Local\Temp\ipykernel_13784\3849299077.py:5: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['Highly Recommended – M-Brothers Automotive Brilliant experience with M-Brothers Automotive. Very experienced and knowledgeable team who clearly know what they’re doing. Customer service was excellent from start to finish, and the prices were very reasonable for the quality of work provided. Honest, reliable, and professional — I’ll definitely be using them again and highly recommend them to anyone needing vehicle repairs. | Outstanding Service and Incredible Trustworthiness!  I cannot recommend M-Brothers Automotive highly enough. I recently brought my car in for a major service that included a full service, ball joint replacement, and a rear differential service. From start to finish, the experience was flawless.  The team was professional, knowledgeable, and took the time to explain exactly what ne
# ...

# %%
df1.head(10)
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       SC780693                    4.7                 NaN
# 1       SC402065                    4.2                 1.0
# 2       SC444940                    4.6                 NaN
# 3       SC857241                    4.7                 2.0
# 4       11215147                    4.8                 NaN
# 5       16519529                    4.6                 1.0
# 6       16379120                    4.5                 1.0
# 7       SC531326                    4.6                 2.0
# 8        8589456                    5.0                 NaN
# 9       15478214                    4.6                 NaN
#
#                                  Google_Review_Texts  \
# 0  Highly Recommended – M-Brothers Automotive Bri...
# 1  Small but friendly establishment. Couple of TV...
# 2  The best vegan pizza in Inverclyde! Absolutely...
# 3  Food was great! My husband said it was the bes...
# ...

# %%
df1.isna().sum()
# Out:
#  CompanyNumber                          0
# Google_Overall_Rating                   0
# Google_Price_Level                  10290
# Google_Review_Texts                    83
# Google_Individual_Review_Ratings        9
# dtype: int64

# %%
len(df1)
# Out:
# 15659

# %%
df2 = pd.read_excel('Query_complete_03_06_26.xlsx')

# %%
df2.head()
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       16113446                    4.7                 NaN
# 1       15106345                    2.5                 NaN
# 2       11826918                    3.2                 1.0
# 3       14359046                    4.7                 NaN
# 4       15359174                    4.5                 NaN
#
#                                  Google_Review_Texts  \
# 0  Dear sir/madam, Just a brief note about your r...
# 1  Friendly and professional team with excellent ...
# 2  I don't know what happened to this place. It u...
# 3  Everything was amazing and the prices were gre...
# 4  Fine fusion is a great local restaurant. Start...
#
#   Google_Individual_Review_Ratings
# 0                4 | 5 | 5 | 5 | 5
# 1                    5 | 1 | 3 | 1
# 2                2 | 5 | 1 | 1 | 5
# 3                5 | 4 | 5 | 5 | 4
# 4                4 | 5 | 3 | 3 | 5

# %%
df2.isna().sum()
# Out:
#  CompanyNumber                         0
# Google_Overall_Rating                  0
# Google_Price_Level                  5664
# Google_Review_Texts                   40
# Google_Individual_Review_Ratings       2
# dtype: int64

# %%
df2.isna().sum()
# Out:
#  CompanyNumber                         0
# Google_Overall_Rating                  0
# Google_Price_Level                  5664
# Google_Review_Texts                   40
# Google_Individual_Review_Ratings       2
# dtype: int64

# %%
df2_sub1 = pd.read_excel('Quer_file_output_03_06_26.xlsx')

# %%
df2_sub1.head()
# Out:
#    CompanyNumber        BusinessName PostCode  Google_Overall_Rating  \
# 0       14584272       DOWNHAM KEBAB   BR14PP                    4.2
# 1       16673526   NEW CHINA COTTAGE   NN55BG                    3.5
# 2       15556160    KARACHI FLAVOURS   B128LG                    4.7
# 3       16950116           98 SIZZLE   B114DA                    4.2
# 4       16164579  PUNJABI DESI TADKA   SN11SG                    4.7
#
#    Google_Price_Level                                Google_Review_Texts  \
# 0                 1.0  Ordered a chicken shish kebab with salad, pitt...
# 1                 2.0  Have always used China Cottage in past which h...
# 2                 NaN  Missing other Aloo parathas which was given on...
# 3                 NaN  I’m the first one reviewing this shop. Their f...
# 4                 NaN  Amazing food, we ate in but probably better fo...
#
#   Google_Individual_Review_Ratings
# 0                1 | 5 | 4 | 5 | 5
# 1                1 | 2 | 5 | 1 | 1
# ...

# %%
df2_sub1 = df2_sub1[[' CompanyNumber','Google_Overall_Rating','Google_Price_Level','Google_Review_Texts','Google_Individual_Review_Ratings']]

# %%
df2_sub1.head()
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       14584272                    4.2                 1.0
# 1       16673526                    3.5                 2.0
# 2       15556160                    4.7                 NaN
# 3       16950116                    4.2                 NaN
# 4       16164579                    4.7                 NaN
#
#                                  Google_Review_Texts  \
# 0  Ordered a chicken shish kebab with salad, pitt...
# 1  Have always used China Cottage in past which h...
# 2  Missing other Aloo parathas which was given on...
# 3  I’m the first one reviewing this shop. Their f...
# 4  Amazing food, we ate in but probably better fo...
#
#   Google_Individual_Review_Ratings
# 0                1 | 5 | 4 | 5 | 5
# 1                1 | 2 | 5 | 1 | 1
# 2                3 | 5 | 5 | 5 | 5
# 3                5 | 4 | 5 | 5 | 5
# 4                5 | 5 | 5 | 5 | 5

# %%
df2_sub1.isna().sum()
# Out:
#  CompanyNumber                        0
# Google_Overall_Rating               520
# Google_Price_Level                  811
# Google_Review_Texts                 523
# Google_Individual_Review_Ratings    521
# dtype: int64

# %%
len(df2)
# Out:
# 8681

# %%
len(df2_sub1)
# Out:
# 928

# %%
df2_sub1 = df2_sub1.dropna(subset = ['Google_Overall_Rating'])

# %%
df2_sub1.isna().sum()
# Out:
#  CompanyNumber                        0
# Google_Overall_Rating                 0
# Google_Price_Level                  291
# Google_Review_Texts                   3
# Google_Individual_Review_Ratings      1
# dtype: int64

# %%
len(df2_sub1)
# Out:
# 408

# %%
final_df = pd.concat([df1,df2,df2_sub1])

# %%
len(final_df)
# Out:
# 24748

# %%
final_df.head()
# Out:
#    CompanyNumber  Google_Overall_Rating  Google_Price_Level  \
# 0       SC780693                    4.7                 NaN
# 1       SC402065                    4.2                 1.0
# 2       SC444940                    4.6                 NaN
# 3       SC857241                    4.7                 2.0
# 4       11215147                    4.8                 NaN
#
#                                  Google_Review_Texts  \
# 0  Highly Recommended – M-Brothers Automotive Bri...
# 1  Small but friendly establishment. Couple of TV...
# 2  The best vegan pizza in Inverclyde! Absolutely...
# 3  Food was great! My husband said it was the bes...
# 4  Best pint of bass I have had in a long time fr...
#
#   Google_Individual_Review_Ratings
# 0                5 | 5 | 5 | 5 | 5
# 1                5 | 5 | 5 | 1 | 5
# 2                5 | 5 | 5 | 5 | 5
# 3                4 | 5 | 1 | 4 | 4
# 4                5 | 5 | 5 | 5 | 5

# %%
master = pd.read_excel('Final Dataset.xlsx',sheet_name = 'Sheet1')

# %%
master.columns
# Out:
# Index([' CompanyNumber', 'CompanyName', 'RegAddress.CareOf',
#        'RegAddress.AddressLine1', ' RegAddress.AddressLine2',
#        'RegAddress.PostTown', 'RegAddress.County', 'RegAddress.Country',
#        'RegAddress.PostCode', 'CompanyCategory', 'CompanyStatus',
#        'Target Value', 'CountryOfOrigin', 'IncorporationDate',
#        'Accounts.AccountRefDay', 'Accounts.AccountRefMonth',
#        'Accounts.NextDueDate', 'Accounts.LastMadeUpDate',
#        'Accounts.AccountCategory', 'Returns.NextDueDate',
#        'Returns.LastMadeUpDate', 'Mortgages.NumMortCharges',
#        'Mortgages.NumMortOutstanding', 'Mortgages.NumMortPartSatisfied',
#        'Mortgages.NumMortSatisfied', 'SICCode.SicText_1', 'SICCode.SicText_2',
#        'SICCode.SicText_3', 'SICCode.SicText_4',
#        'LimitedPartnerships.NumGenPartners',
#        'LimitedPartnerships.NumLimPartners', 'URI', 'PreviousName_1.CONDATE',
#        ' PreviousName_1.CompanyName', ' PreviousName_2.CONDATE',
# ...

# %%
final_df[' CompanyNumber'] = final_df[' CompanyNumber'].astype(str).str.zfill(8)
master[' CompanyNumber'] = master[' CompanyNumber'].astype(str).str.zfill(8)

# 2. Perform the merge
df_combined = final_df.merge(master, on=' CompanyNumber', how='left')

# %%
len(df_combined)
# Out:
# 24748

# %%
df_combined.to_excel('Merged_Final_Dataset.xlsx',index = False)
